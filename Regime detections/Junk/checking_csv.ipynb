# %%
import pandas as pd

print("Checking CSV file...")

# Load without specifying Date as index
data = pd.read_csv('data/spy_raw.csv')

print("\nColumn names:")
print(data.columns.tolist())

print("\nFirst 5 rows:")
print(data.head())

print("\nData types:")
print(data.dtypes)
# Out:
# Checking CSV file...
#
# Column names:
# ['Price', 'Close', 'High', 'Low', 'Open', 'Volume']
#
# First 5 rows:
#         Price              Close                High                 Low  \
# 0      Ticker                SPY                 SPY                 SPY
# 1        Date                NaN                 NaN                 NaN
# 2  2019-01-02  224.9953155517578  225.92164195797136  221.19113755446438
# 3  2019-01-03  219.6262969970703   223.5473926222731  219.14064909646268
# 4  2019-01-04  226.9828643798828  227.63038583409028  222.28834069825123
#
#                  Open     Volume
# 0                 SPY        SPY
# 1                 NaN        NaN
# 2   221.2181164696921  126925200
# 3  223.24160872373565  144140700
# 4  222.66605925941474  142628800
#
# Data types:
# Price     object
# Close     object
# High      object
# Low       object
# Open      object
# Volume    object
# dtype: object
